# %%
hello = {23,23, 43 ,12,"hi","python"}
hello .discard(23)
print(hello)
# Out:
# {'hi', 'python', 43, 12}

# %%
hello = {23,23, 43 ,12,"hi","python"}
hello .remove("hi")
print(hello)
# Out:
# {23, 'python', 43, 12}

# %%
hello = {23,23, 43 ,12,"hi","python"}
set2 = {56,76,60,"elements"}
# x= hello.union(set2)
x = hello.intersection(set2)
print(x)
# Out:
# set()

# %%
import pandas as pd
import numpy as np
df = pd.read_csv( '/content/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  passenger_class  \
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 886                     Montvila, Rev. Juozas    male  27.0      0      0
# 887              Graham, Miss. Margaret Edith  female  19.0      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                     Behr, Mr. Karl Howell    male  26.0      0      0
# 890                       Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 886      211536  13.00   NaN        S
# 887      112053  30.00   B42        S
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q

# %%
df.rename(columns={'Pclass':'passenger_class'}, inplace=True)
df
# Out:
#      PassengerId  Survived  passenger_class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.iloc[0,0:]
# Out:
# PassengerId                              1
# Survived                                 0
# passenger_class                          3
# Name               Braund, Mr. Owen Harris
# Sex                                   male
# Age                                   22.0
# SibSp                                    1
# Parch                                    0
# Ticket                           A/5 21171
# Fare                                  7.25
# Cabin                                  NaN
# Embarked                                 S
# Name: 0, dtype: object

# %%
df.iloc[0:,3]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.iloc[0:3,0:]
# Out:
#    PassengerId  Survived  passenger_class  \
# 0            1         0                3
# 1            2         1                1
# 2            3         1                3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# df.iloc[886:891]
df.iloc[-5:,]
# Out:
#      PassengerId  Survived  passenger_class  \
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 886                     Montvila, Rev. Juozas    male  27.0      0      0
# 887              Graham, Miss. Margaret Edith  female  19.0      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                     Behr, Mr. Karl Howell    male  26.0      0      0
# 890                       Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 886      211536  13.00   NaN        S
# 887      112053  30.00   B42        S
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q

# %%
df.loc[0:4,'Name':'Age']
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df.loc[df["Age"]==50,:]
# Out:
#      PassengerId  Survived  passenger_class  \
# 177          178         0                1
# 259          260         1                2
# 299          300         1                1
# 434          435         0                1
# 458          459         1                2
# 482          483         0                3
# 526          527         1                2
# 544          545         0                1
# 660          661         1                1
# 723          724         0                2
#
#                                                 Name     Sex   Age  SibSp  \
# 177                       Isham, Miss. Ann Elizabeth  female  50.0      0
# 259                      Parrish, Mrs. (Lutie Davis)  female  50.0      0
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 434                        Silvey, Mr. William Baird    male  50.0      1
# 458                              Toomey, Miss. Ellen  female  50.0      0
# ...

# %%
df.Shape()
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-cf1c0d65d821> in <cell line: 1>()
# ----> 1 df.Shape()
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Shape'

# %%
df.describe()
df
# Out:
#      PassengerId  Survived  passenger_class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"].nunique()
# Out:
# 3

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# lambda function : a special type of function followed by the variables , colon and expression .

# %%
def cube(a) :
    return a**3

print(cube(2))
# Out:
# 8

# %%
cube = lambda a : a**3
print(cube(2))
# here lambda is predefined
# Out:
# 8

# %%
df
# Out:
#      PassengerId  Survived  passenger_class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
# # df.loc[df["Sex"]=="female"]
# df.loc[df["Age"]==50,"Sex"=="female"]
df.loc[(df["Age"]==50)&(df["Sex"]=="female")]
# Out:
#      PassengerId  Survived  passenger_class  \
# 177          178         0                1
# 259          260         1                2
# 299          300         1                1
# 458          459         1                2
# 526          527         1                2
#
#                                                 Name     Sex   Age  SibSp  \
# 177                       Isham, Miss. Ann Elizabeth  female  50.0      0
# 259                      Parrish, Mrs. (Lutie Davis)  female  50.0      0
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 458                              Toomey, Miss. Ellen  female  50.0      0
# 526                             Ridsdale, Miss. Lucy  female  50.0      0
#
#      Parch        Ticket      Fare    Cabin Embarked
# 177      0      PC 17595   28.7125      C49        C
# 259      1        230433   26.0000      NaN        S
# 299      1      PC 17558  247.5208  B58 B60        C
# ...

# %%
def extractname(name):
    x = name.split(',')
    # return x[0]
    return x[1]
    # print(x)

# df["Name"].apply(extractname)
# df['lastname'] = df['Name'].apply(extractname)
df["firstname"] = df['Name'].apply(extractname)
df
# Out:
#      PassengerId  Survived  passenger_class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# ...

# %%
# df['Sex'].replace(['male', 'female'], [0, 1], inplace=True)
# df
df ["encoded"]= df['Sex'].map({"male ":1,"female ":0})
df
# Out:
#      PassengerId  Survived  passenger_class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# ...

# %%
df[df.Age == df.Age.max()]
# df[df.Age == df.Age.min()]
# Out:
#      PassengerId  Survived  passenger_class  \
# 630          631         1                1
#
#                                      Name  Sex   Age  SibSp  Parch Ticket  \
# 630  Barkworth, Mr. Algernon Henry Wilson    0  80.0      0      0  27042
#
#      Fare Cabin Embarked   lastname                   firstname  encoded
# 630  30.0   A23        S  Barkworth   Mr. Algernon Henry Wilson      NaN

# %%
x = [10,12,20,30,40]
50 in x
# Out:
# False

# %%
x = [10,12,20,30,40]
50 not in x
# Out:
# True

# %%
x = [10,12,20,30,40]
y = x
x is y
# Out:
# True
